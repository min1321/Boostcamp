# %% [markdown]
# # (11강) 돌아보기
#
# ## Further Question
# 1) 이번 강의는 lightweight modeling과 어떤 관계가 있을까? (이 강의를 만든 목적은 무엇일까?)
#
# 2) 이번 강의에서 인상깊었던 키워드를 5개 적어보자
#
# 3) 이번 강의를 수강하는 동안 좋았던 점은? 그 좋았던 점을 앞으로 자주 겪으려면 어떤 action을 해볼 수 있을까?
#
# 4) 이번 강의를 수강하는 동안 아쉬웠던 순간은? 그 아쉬움을 어떻게 완화할 수 있을까?
#
# 5) 이번 강의를 내 손으로 만든다면 나는 어떻게 만들어볼 수 있을까?

# %% [markdown]
# ## Retrospect
# - 경량화가 무엇인지 전반적인 이야기를 했음
# - 목차
#     ![image.png](attachment:image.png)
