# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
torch.manual_seed(1)
# 데이터
x_train = torch.FloatTensor([[80], [90], [100], [110], [120]])
y_train = torch.FloatTensor([[60], [70], [80], [90], [100]])
# 모델을 선언 및 초기화. 단순 선형 회귀이므로 input_dim=1, output_dim=1.
model = nn.Linear(1,1)
print(list(model.parameters()))
# optimizer 설정. 경사 하강법 SGD를 사용하고 learning rate를 의미하는 lr은 0.01
LR = 0.01
optimizer = torch.optim.SGD(model.parameters(), lr=LR) 
# 전체 훈련 데이터에 대해 경사 하강법을 2,000회 반복
nb_epochs = 2000
for epoch in range(nb_epochs+1):
    # H(x) 계산
    prediction = model(x_train)
    # cost 계산
    cost = F.mse_loss(prediction, y_train) # <== 파이토치에서 제공하는 평균 제곱 오차 함수
    # cost로 H(x) 개선하는 부분
    # gradient를 0으로 초기화
    optimizer.zero_grad()
    # 비용 함수를 미분하여 gradient 계산
    cost.backward() # backward 연산
    # W와 b를 업데이트
    optimizer.step()
    
    if epoch % 10 == 0:
    # 100번마다 로그 출력
      print('Epoch {:4d}/{} Cost: {:.6f}'.format(
          epoch, nb_epochs, cost.item()
      ))
# Out:
# [Parameter containing:
# tensor([[0.5153]], requires_grad=True), Parameter containing:
# tensor([-0.4414], requires_grad=True)]
# Epoch    0/2000 Cost: 883.074585
# Epoch   10/2000 Cost: inf
# Epoch   20/2000 Cost: nan
# Epoch   30/2000 Cost: nan
# Epoch   40/2000 Cost: nan
# Epoch   50/2000 Cost: nan
# Epoch   60/2000 Cost: nan
# Epoch   70/2000 Cost: nan
# Epoch   80/2000 Cost: nan
# Epoch   90/2000 Cost: nan
# Epoch  100/2000 Cost: nan
# Epoch  110/2000 Cost: nan
# Epoch  120/2000 Cost: nan
# Epoch  130/2000 Cost: nan
# Epoch  140/2000 Cost: nan
# Epoch  150/2000 Cost: nan
# Epoch  160/2000 Cost: nan
# Epoch  170/2000 Cost: nan
# Epoch  180/2000 Cost: nan
# Epoch  190/2000 Cost: nan
# Epoch  200/2000 Cost: nan
# Epoch  210/2000 Cost: nan
# Epoch  220/2000 Cost: nan
# Epoch  230/2000 Cost: nan
# Epoch  240/2000 Cost: nan
# Epoch  250/2000 Cost: nan
# Epoch  260/2000 Cost: nan
# Epoch  270/2000 Cost: nan
# Epoch  280/2000 Cost: nan
# Epoch  290/2000 Cost: nan
# Epoch  300/2000 Cost: nan
# Epoch  310/2000 Cost: nan
# Epoch  320/2000 Cost: nan
# Epoch  330/2000 Cost: nan
# Epoch  340/2000 Cost: nan
# Epoch  350/2000 Cost: nan
# Epoch  360/2000 Cost: nan
# Epoch  370/2000 Cost: nan
# Epoch  380/2000 Cost: nan
# Epoch  390/2000 Cost: nan
# Epoch  400/2000 Cost: nan
# Epoch  410/2000 Cost: nan
# Epoch  420/2000 Cost: nan
# Epoch  430/2000 Cost: nan
# Epoch  440/2000 Cost: nan
# Epoch  450/2000 Cost: nan
# Epoch  460/2000 Cost: nan
# Epoch  470/2000 Cost: nan
# Epoch  480/2000 Cost: nan
# Epoch  490/2000 Cost: nan
# Epoch  500/2000 Cost: nan
# Epoch  510/2000 Cost: nan
# Epoch  520/2000 Cost: nan
# Epoch  530/2000 Cost: nan
# Epoch  540/2000 Cost: nan
# Epoch  550/2000 Cost: nan
# Epoch  560/2000 Cost: nan
# Epoch  570/2000 Cost: nan
# Epoch  580/2000 Cost: nan
# Epoch  590/2000 Cost: nan
# Epoch  600/2000 Cost: nan
# Epoch  610/2000 Cost: nan
# Epoch  620/2000 Cost: nan
# Epoch  630/2000 Cost: nan
# Epoch  640/2000 Cost: nan
# Epoch  650/2000 Cost: nan
# Epoch  660/2000 Cost: nan
# Epoch  670/2000 Cost: nan
# Epoch  680/2000 Cost: nan
# Epoch  690/2000 Cost: nan
# Epoch  700/2000 Cost: nan
# Epoch  710/2000 Cost: nan
# Epoch  720/2000 Cost: nan
# Epoch  730/2000 Cost: nan
# Epoch  740/2000 Cost: nan
# Epoch  750/2000 Cost: nan
# Epoch  760/2000 Cost: nan
# Epoch  770/2000 Cost: nan
# Epoch  780/2000 Cost: nan
# Epoch  790/2000 Cost: nan
# Epoch  800/2000 Cost: nan
# Epoch  810/2000 Cost: nan
# Epoch  820/2000 Cost: nan
# Epoch  830/2000 Cost: nan
# Epoch  840/2000 Cost: nan
# Epoch  850/2000 Cost: nan
# Epoch  860/2000 Cost: nan
# Epoch  870/2000 Cost: nan
# Epoch  880/2000 Cost: nan
# Epoch  890/2000 Cost: nan
# Epoch  900/2000 Cost: nan
# Epoch  910/2000 Cost: nan
# Epoch  920/2000 Cost: nan
# Epoch  930/2000 Cost: nan
# Epoch  940/2000 Cost: nan
# Epoch  950/2000 Cost: nan
# Epoch  960/2000 Cost: nan
# Epoch  970/2000 Cost: nan
# Epoch  980/2000 Cost: nan
# Epoch  990/2000 Cost: nan
# Epoch 1000/2000 Cost: nan
# Epoch 1010/2000 Cost: nan
# Epoch 1020/2000 Cost: nan
# Epoch 1030/2000 Cost: nan
# Epoch 1040/2000 Cost: nan
# Epoch 1050/2000 Cost: nan
# Epoch 1060/2000 Cost: nan
# Epoch 1070/2000 Cost: nan
# Epoch 1080/2000 Cost: nan
# Epoch 1090/2000 Cost: nan
# Epoch 1100/2000 Cost: nan
# Epoch 1110/2000 Cost: nan
# Epoch 1120/2000 Cost: nan
# Epoch 1130/2000 Cost: nan
# Epoch 1140/2000 Cost: nan
# Epoch 1150/2000 Cost: nan
# Epoch 1160/2000 Cost: nan
# Epoch 1170/2000 Cost: nan
# Epoch 1180/2000 Cost: nan
# Epoch 1190/2000 Cost: nan
# Epoch 1200/2000 Cost: nan
# Epoch 1210/2000 Cost: nan
# Epoch 1220/2000 Cost: nan
# Epoch 1230/2000 Cost: nan
# Epoch 1240/2000 Cost: nan
# Epoch 1250/2000 Cost: nan
# Epoch 1260/2000 Cost: nan
