# %% [markdown]
# # 뉴럴 네트워크(MLP)

# %% [markdown]
# ### 이번 강의에서 중요한 내용
# - 신경망 (Neural Networks)
#     - Data, Model, Loss, Optimization algrithm
# - Deep Neural Networks
#     - Multi-layer perceptron과 같이 더 깊은 네트워크는 어떻게 구성하는지?

# %% [markdown]
# ## 신경망
# - 인강의 뇌를 모방했다
# - 사람의 지능을 모방했다고 보기는 어려움
# - 비행기가 새를 모방했다고 하지만 사실 그렇게 발달하진 않음
#     - 사람이 날고싶다고 해서 새를 너무 모방할 필요는 없음
# - 시작은 뇌를 모방했을지 모르지만, 지금의 뉴럴네트워크의 동작은 인간의 뇌와는 너무 많이 갈라졌다
#     - 그 자체로 수학적으로 분석하자
# - 수학적인 함수를 근사하는 모델이다고 보는 것이 더 맞다고 생각함
#     - 비 선형적인 연산을 반복하는 것
# - 간단한 예제 (선형 회귀)
# ![image.png](attachment:image.png)
#     - 어떻게 W를 찾을까? : 어느방향으로 파라미터를 바꾸는게 로스를 줄일 것인가
# ![image-2.png](attachment:image-2.png)
# ![image-4.png](attachment:image-4.png)
# - 여러 차원의 이동?
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)
# - 위의 여러 곱은 어짜피 선형을 여러번 연산하기때문에 여전히 선형이다.
# - 아래처럼 비선형으로 변형 시켜줄 수 있는 Activation functions 필요
# ![image-7.png](attachment:image-7.png)
# - Activation functions으로 변형이 필요함
# ![image-8.png](attachment:image-8.png)

# %% [markdown]
# ## Multi-Layer Perceptron
# ![image.png](attachment:image.png)
# - Loss Function ?
#     - MSE : Regression Task
#         - Error가 큰 Target data가 있으면, 크게 흔들리게됨
#     - CE : Classification Task
#         - 분류를 한다는 것은 다른 9개의 값에 비해 y 번째 값만 크면 됨
#         - 분류 문제를 푸는데 최적일까?
#     - MLE : Probabilistic Task
# ![image-2.png](attachment:image-2.png)
