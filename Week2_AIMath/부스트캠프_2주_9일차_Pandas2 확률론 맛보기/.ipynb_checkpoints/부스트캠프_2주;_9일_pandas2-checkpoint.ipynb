# %% [markdown]
# # 중요한것
#     - pandas로 통계에 사용되는 내용 실습해보는 것이 중요

# %% [markdown]
# ## groupby
# - 아래와 같은 과정을 거쳐서 연산함

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 피벗 테이블과 같은 느낌 (groupby)
#     - 여러 집단이 그룹으로 묶을  수 있는 집단이 있으면 함수로 넣어줌
#     - df.groupby(["Team", "Year"])["Points"].sum()
#     - 위와 같은 형태로 사용함

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - groupby
#     - grouped
#         - 그룹by로 split 상태를 추출 가능함 (아래와 같이 출력하려면?
#             - 팀명
#                 내용

# %% [markdown]
# - grouped 된 상태에서 할수 있는 것들이 많음
#     - 요약된 통계정보, sum min등, transformation, filter)
#     - sum min 등 apply 가능

# %% [markdown]
# - transformation을 이용한 정규화?? (아래 그림 참조)
#     - transformation은 모든 data에 같은 식을 적용시켜줌

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - groupby filter는 잘은 사용 안할 것 같음

# %% [markdown]
# - add_prefix 함수는 무엇을 하는 것일까?
#     - 컬럼 앞에 원하는 멘트 추가 가능 (아래사진 참조)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - pivot table (엑셀에 익숙한 사람은 이것 쓰면 됨)
#     - groupby 쉽게 할 수 있는것
#     - 아래와 같이 인자로는 연산을 하고싶은 대상 먼저 정하고, index, columns, aggfunc, fill_value 순으로 인자를 넣으면 됨

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - crosstab
#     - 특히 두 컬럼의 교차빈도, 비율, 덧셈을 구할때 사용
#     - pibot table의 특수한 형태

# %% [markdown]
# - Merge & concat
#     - Merge는
#         - SQL에서 많이 사용하는 개념
#         - A,B를 합칠때 사용
#         - on은 양쪽에 같은 값이 있을때만 합침
#         - left_on, right_on 을 이용해서 각각 합칠 수 있음

# %% [markdown]
# - merge Join 규칙

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 그렇다면 concat이란??
#     - concat은 값을 붙이는 것임
#     - 기본적으로 list 형태로 값을 붙이게 됨

# %% [markdown]
# - persistence
#     - IO 를 할 수 있는 것이 sql문인데 select를
#     - 파이썬에서 서버나 데이터베이스에서 불러오는 방법도 있다!

# %%
# !conda install --y XlsxWriter
# --y라고 예스를 해줘야하는데 여기서 칠수 없으니 --y를 입력한 것입니다.
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %% [markdown]
# - 저는 pickle 형태로 저장하는 것을 선호합니다.
#     - 바로 읽어와서 쓸 수 있음
