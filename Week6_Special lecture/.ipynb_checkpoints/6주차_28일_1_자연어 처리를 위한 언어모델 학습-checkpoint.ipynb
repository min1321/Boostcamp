# %% [markdown]
# # 자연어 처리를 위한 언어 모델의 학습과 평가
#
# ## 언어 모델링
# ---
# - 주어진 문맥을 활용해 다음에 나타날 단어 예측하기
# - 양방향 언어 모델링 (ELMo 에서 처음 소개)
# ![image.png](attachment:image.png)
# - 양방향 언어 모델링 예시2 BERT
#     - 사전 학습된 모델이 자연어 처리 자체를 잘한다
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
#
# - QQP 두문장이 얼마나 유사한지
# - QNLI 두문장이 모순이 있는지? 상세한 설명하는 것인지를 분류
# - SST 이문장의 뉘앙스가 긍정인지 부정인지
# - CoLA 사람이 읽었을때 문법상 문제 없이 받아들일수 있는지
# - STS-B, MRPC 두개 문장이 유사한지?
# - RTE 자연어 추론
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ## 언어 모델의 평가
# - GLUE 벤치마크
#     - 언어 모델이 얼마나 사람의 언어를 잘 이해하는지?
#     - 자연어 생성을 어떻게 잘 할 수 있는가에도 사용됨
#     ![image.png](attachment:image.png)
#     ![image-3.png](attachment:image-3.png)
# - 다국적 벤치마크의 등장
#     ![image-4.png](attachment:image-4.png)
# - 한국어 자연어 이해 밴치마크(KLUE)
# ![image-5.png](attachment:image-5.png)
