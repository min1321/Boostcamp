# %% [markdown]
# # (실습)Image captioning
#
# ## Encoder
# - 모듈을 쓸때 끝에 2개 잘라서 사용
#     - 마지막 2개는 Classification 부분이고 우리는 classification을 안할거라서
#     - 그리고 공간정보를 받아야하기 때문에 Vector가 아니게 하기 위해
#     - 결과가 14x14가 되도록 init에서 설정해줬음
#     ![image.png](attachment:image.png)
#
# ## Decoder
# ![image-2.png](attachment:image-2.png)
#
# ## Beam search
# - 단어 예를들어 만개 중에서 어떤것을 출력할 것인지?
#     - a를 선택했는데 사실은 The를 쓰는게 더 좋았을수도 있음
#     - k=3 이라면, 3개를 뽑고 각각 3개의 가능성 즉 9개를 뽑고 그중에 3개를 선정해서 계속 넘겨주는 방식
#     ![image-3.png](attachment:image-3.png)
