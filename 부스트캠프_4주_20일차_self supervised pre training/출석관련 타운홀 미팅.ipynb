# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 마스터 클래스 질문
# - 마스터 세션에서만 할 수 있는 질문
# - 따뜻함이 전달되는 질문이 좋음
# - 나의 상황이 설명된 질문
