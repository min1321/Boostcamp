# %% [markdown]
# # 스터디 추가학습 내용
# - Adversarial attack : 테슬라 같은 경우, 이루다 같은 경우, 현실에 잘 없을 데이터를 학습시켜서 오판단을 내리게 하여 공격하는 것
#     - 예를들어 표지판에 선이 몇개 그어져 있으면 다른 표지판으로 인식 한다던가 하는 식으로
# - defence against adversarial attack : 위에 저걸 막아주는 것을 잘 설계하는 것

# %% [markdown]
# ## NFNets 최신 기술 이해
# - Large size 이미지를 학습시킬 때 좋다고 함. batch normalization을 쓰면 파라미터가 너무 많아져서, 줄여주는 NFNets을 쓰면 좋음
#
# ### batch normalizaion을 없애고 다른 기술들을 넣은것
# - batch normalization은 왜 뺐나?
#     -
#
# - SAM optimizer
#     - Loss 그래프를 보면 Sharp
# ![image.png](attachment:image.png)
#
# - Drop out도 사용했음
