# %% [markdown]
# # Convolution은 무엇인가?
# ### 알아야 할 것
# - CNN에서 가장 중요한 연산은 Convolution입니다.
# - Convolution의 정의, Convolution 연산 방법과 기능
# - 기본적인 CNN 구조
# - CNN 실습

# %% [markdown]
# - Convolution을 한다는 것은 도장을 찍는것과 유사함
#     - 한칸씩 이동하면서 찍은 결과를 output에 넣음
# - convolution 기능?
# ![image.png](attachment:image.png)

# %% [markdown]
# - 일반적인 RGB에 필터를 씌우면?
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# - 한번 Conv 거치면 Nonlinear Activation 필요

# %% [markdown]
# - conv filter 크기는 아래 보면서 생각해보기
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Convolutional 과 pooling layer 역할
# - 이미지에서 유용한 정보를 뽑아주는 역할
#
# ### fully connected layer 역할?
# - 분류를 해주는 역할

# %% [markdown]
# - 요즘 Trend?
#     - fully connected layer 없어지는 추세
#     - 같은 모델을 만들고 최대한 Deep하게 들어가면서 파라미터는 줄이는 방향으로 발전중

# %% [markdown]
# - 숙제
#     - 어떤 뉴럴 네트워크에서 파라미터 숫자 세어보기

# %% [markdown]
# ### Stride 개념?
# - 넓게 걷는다는 의미
# - step 처럼 한번에 몇칸씩 뛰고 찍는지

# %% [markdown]
# ### Padding
# - 32*32 에 필터를 씌우면, 바운더리 이미지가 사라져서 줄어듬.
# - 아웃풋 이미지 줄어드는 것 방지를 위해서 가장자리에 패딩을 씌워줌

# %% [markdown]
# ### Convolution Arithmetic
# - 아까 나왔던 숙제는 아래와 같은 방법으로 파라미터 수를 세어주면 됨 (몇 만 단위인지 보면 바로 나와야함)
#     - 여기서 파라미터 수는 Filter의 입력값 수인 것 같음
# ![image.png](attachment:image.png)

# %% [markdown]
# - 아래 알렉스넷에서 파라미터 갯수 찾아보기

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Dense layer 가 parameter 수가 거의 1000배 차이남
#     - why??
#         - 컨벌루셔널 오퍼레이터가 각각의 위치에서 동일하게 적용됨
#         - 같은 커널이 동일하게 이동하면서 적용시키는 것이기 때문에 그럼
#     - So what?
#         - 그래서 앞단에서 Conv Layer는 많이쌓고 Fully connected는 줄이는 중

# %% [markdown]
# - 1X1Convolution은 왜할까?
#     - Chenal을 줄이는 것 (즉 파라미터 수를 줄일 수 있음)
#     ![image.png](attachment:image.png)
