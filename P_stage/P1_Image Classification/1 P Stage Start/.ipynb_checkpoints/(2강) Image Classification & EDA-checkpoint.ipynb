# %% [markdown]
# # (2강) Image Classification & EDA
#
# ## 강의 소개
# - EDA의 의미와 EDA를 어떻게 해야 하는지
# - Image(Input) -> Classfication Model  -> Class(Output)
# - 베이스라인 활용법

# %% [markdown]
# ## Overview
# ---
# ![image.png](attachment:image.png)
#
# ## EDA(Exploratory Data Analysis)
# ---
# - EDA란?
#     - 탐색적 데이터 분석, 데이터를 이해하기 위한 노력
# - EDA에서 무엇을 할지?
#     - 주어진 데이터에 대한 본인의 생각을 자유롭게 서술하시오
#         ![image-2.png](attachment:image-2.png)
#     - 어떤 생각을 가져야할지? (접근방법)
#         - 과연 EDA를 너무 어렵게 생각하는건 아닌가?
#         - 내가 분석하는데 어려움을 느끼는 곳은 어디인가?
# - EDA의 진짜 목적
#     - 진짜로 궁금한건 뭐지?
#         - 실제로 어떻게 생겼는지?
#         - 주제랑 연관성?
#         - 궁금, 알고 싶은 것?
#         - 메터데이터의 분포
#         - 주어진 데이터 타입의 특성?
#     - 도구
#         - 일일이 손으로
#         - python
#         - excel
#         - 등등..

# %% [markdown]
# ## 다시 돌아옴
# ---
# - 모델을 돌리다가도, 궁금해 지면 다시 EDA를 하면 됨
# - 처음에는 아무렇게나 해보자!
# - 이미지 쪽에서는 EDA 해볼수 있는게 많지는 않을 수 있음
#
# ## Image Classification
# ---
# - Image
#     - 시작적 인식을 표현한 인공물
#     - dtype : uint8는 음수는 빼고 255까지 양수로 표현하는 것
# - Model
#     - Input + Model = Output
#     ![image.png](attachment:image.png)
#     - image + classification model = class
#         - 어떻게 이미지를 넣을지?
#         - int를 Float로?
#         - size는 어떻게 바꿀지?
#
# ## Baseline
# ---
# - 장단이 있음
#     - 있으면, 스스로하는 학습이 잘 안될 수 있음
#     - 그래서, 스스로 한번 만들어보고, 예시 코드랑 비교해보자 (생각하지 못한 부분 발견)
# - 점점 코드는 더해질 계획임
#     ![image-2.png](attachment:image-2.png)
